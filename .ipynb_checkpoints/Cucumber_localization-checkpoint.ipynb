# %%
# import os
import cv2
import numpy as np
# import pandas as pd
import tensorflow as tf
import xml.etree.ElementTree as xt
import plotly.express as px
# import matplotlib.pyplot as plt
# import plotly.express as px

# from PIL import Image
# from skimage import io
from glob import glob
from tensorflow.keras.models import Model
from bs4 import BeautifulSoup
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam,RMSprop
from tensorflow.keras.layers import Dense, Dropout, Flatten

import xml.etree.ElementTree as ET
import pandas as pd

# %%
xml_example = 'training_images/training_images/cucumber_1.xml'

with open(xml_example, 'r') as f:
    data = f.read()
    content = BeautifulSoup(data, 'xml')
content
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <annotation>
# <folder>single cucumber</folder>
# <filename>cucumber_1.jpg</filename>
# <path>C:\Users\Muhammed Buyukkinaci\Downloads\single cucumber\cucumber_1.jpg</path>
# <source>
# <database>Unknown</database>
# </source>
# <size>
# <width>227</width>
# <height>227</height>
# <depth>3</depth>
# </size>
# <segmented>0</segmented>
# <object>
# <name>cucumber</name>
# <pose>Unspecified</pose>
# <truncated>0</truncated>
# <difficult>0</difficult>
# <bndbox>
# <xmin>23</xmin>
# <ymin>42</ymin>
# <xmax>206</xmax>
# <ymax>199</ymax>
# </bndbox>
# </object>
# </annotation>

# %%
path = sorted(glob('training_images/training_images/*.xml'))# get all elements in path with xml extension
y = [] #create a list to store our targets
for file in path:# loop over each file path and parse it
    label = 0
    info = xt.parse(file) 
    root = info.getroot() 
    obj = root.find('object')
    
    label_obj = (obj.find('name').text)
    if "cucumber" in label_obj:  
        label = 1
    elif "eggplant" in label_obj:
        label = 2
    elif "mushroom" in label_obj:
        label = 3

    bndbox = obj.find('bndbox')
    xmin = (bndbox.find('xmin').text)
    xmax = (bndbox.find('xmax').text)
    ymin = (bndbox.find('ymin').text)
    ymax = (bndbox.find('ymax').text)
    
    #append the results to our target
    y.append([int(label),int(xmin),int(ymin),int(xmax),int(ymax)])

# %%
y[0]
# Out:
# [1, 23, 42, 206, 199]

# %%
# X = []
# images_path = sorted(glob('training_images/training_images/*.jpg'))# get all elements in path with jpg extension

# for image in images_path:#loop over image path
#     img = cv2.imread(image, cv2.COLOR_BGR2RGB)# read the image in rgb mode
#     X.append(img)
import cv2
from glob import glob

X = []
images_path = sorted(glob('training_images/training_images/*.jpg'))  # Get all images in the directory

for image in images_path:
    img = cv2.imread(image, cv2.IMREAD_GRAYSCALE)  # Read the image in grayscale mode
    X.append(img)

# %%
X[0].shape
# Out:
# (227, 227)

# %%
X = np.expand_dims(X, axis=-1)

# %%
img = X[0]
bbox = y[0][1:]
y[1][1:] #view the bbox coordinates
# Out:
# [13, 70, 219, 160]

# %%
print(type(img))
print(img.shape)
print(img.min(), img.max())
# Out:
# <class 'numpy.ndarray'>
# (227, 227, 1)
# 45 255

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.imshow(img)
rect = patches.Rectangle(
    (bbox[0], bbox[1]),           # Bottom-left corner
    bbox[2] - bbox[0],            # Width
    bbox[3] - bbox[1],            # Height
    linewidth=2, edgecolor='cyan', facecolor='none'
)
ax.add_patch(rect)

# Remove axis and display
ax.axis('off')
plt.show()

# %%
X = np.array(X)
y =  np.array(y)

# %%
# X

# %%
# y

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.05)

# %%
categ_train = y_train[:,0:1]
categ_test = y_test[:,0:1]
bbox_train = y_train[:,1:]
bbox_test = y_test[:,1:]
categ_train.shape,categ_test.shape,bbox_train.shape,bbox_test.shape
# Out:
# ((176, 1), (10, 1), (176, 4), (10, 4))

# %%
bbox_train=bbox_train/227.0
bbox_test=bbox_test/227.0

# %%
categ_train[0]
# Out:
# array([3])

# %%
categ_train = tf.keras.utils.to_categorical(categ_train)
categ_test = tf.keras.utils.to_categorical(categ_test)

# %%
categ_train.shape
# Out:
# (176, 4)

# %%
categ_train[0]
# Out:
# array([0., 0., 0., 1.], dtype=float32)

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.regularizers import l2

# Input Shape
input_shape = (227, 227, 1)  # Grayscale images (adjust if different)

# Parameters
num_classes = categ_train.shape[1]  # Number of classes (e.g., 4 if [0, 1, 2, 3])

# Input Layer
image_input = Input(shape=input_shape, name='image_input')

# Shared Feature Extraction Layers (CNN Backbone)
x = Conv2D(16, (3, 3), activation='relu', padding='same' ,kernel_regularizer=l2(1e-4))(image_input)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(1e-4))(x)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(512, activation='relu', kernel_regularizer=l2(1e-4))(x)
x = Dropout(0.5)(x)

# Classification Head
class_output = Dense(num_classes, activation='softmax', name='class_output')(x)

# Bounding Box Regression Head
bbox_output = Dense(4, name='bbox_output')(x)

# Create the Model
model = Model(inputs=image_input, outputs=[class_output, bbox_output])

# Compile the Model
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss={
        'class_output': 'categorical_crossentropy',  # Classification loss
        'bbox_output': 'mse',  # Bounding box regression loss
    },
    metrics={
        'class_output': 'accuracy',  # For classification head
        'bbox_output': 'mse',  # For bounding box regression head
    }
)

# Model Summary
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(None, 227, 227, 1  0           []
#                                 )]
#
#  conv2d_21 (Conv2D)             (None, 227, 227, 16  160         ['image_input[0][0]']
#                                 )
#
#  max_pooling2d_21 (MaxPooling2D  (None, 113, 113, 16  0          ['conv2d_21[0][0]']
#  )                              )
#
#  conv2d_22 (Conv2D)             (None, 113, 113, 32  4640        ['max_pooling2d_21[0][0]']
#                                 )
#
#  max_pooling2d_22 (MaxPooling2D  (None, 56, 56, 32)  0           ['conv2d_22[0][0]']
#  )
#
#  conv2d_23 (Conv2D)             (None, 56, 56, 64)   18496       ['max_pooling2d_22[0][0]']
#
#  max_pooling2d_23 (MaxPooling2D  (None, 28, 28, 64)  0           ['conv2d_23[0][0]']
#  )
#
#  conv2d_24 (Conv2D)             (None, 28, 28, 128)  73856       ['max_pooling2d_23[0][0]']
#
#  max_pooling2d_24 (MaxPooling2D  (None, 14, 14, 128)  0          ['conv2d_24[0][0]']
#  )
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 256)  295168      ['max_pooling2d_24[0][0]']
#
#  max_pooling2d_25 (MaxPooling2D  (None, 7, 7, 256)   0           ['conv2d_25[0][0]']
#  )
#
#  flatten_4 (Flatten)            (None, 12544)        0           ['max_pooling2d_25[0][0]']
#
#  dense_4 (Dense)                (None, 512)          6423040     ['flatten_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 512)          0           ['dense_4[0][0]']
#
#  class_output (Dense)           (None, 4)            2052        ['dropout_4[0][0]']
#
#  bbox_output (Dense)            (None, 4)            2052        ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 6,819,464
# Trainable params: 6,819,464
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# def scheduler(epoch, lr):
#     """
#     Applies exponential decay
#     Args:
#     epoch: Epoch to start the decay at
#     lr: current learning rate
#     """
#     if epoch < 40:
#         return lr
#     else:
#         return lr * tf.math.exp(-0.12)
    
# callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
r=model.fit(X_train,[categ_train,bbox_train],epochs=200,validation_data=(X_test,[categ_test,bbox_test]),batch_size=2)
# Out:
# Epoch 1/200
# 88/88 [==============================] - 2s 13ms/step - loss: 44.8811 - class_output_loss: 4.3376 - bbox_output_loss: 40.4308 - class_output_accuracy: 0.3239 - bbox_output_mse: 40.4308 - val_loss: 1.9399 - val_class_output_loss: 1.6593 - val_bbox_output_loss: 0.1802 - val_class_output_accuracy: 0.1000 - val_bbox_output_mse: 0.1802
# Epoch 2/200
# 88/88 [==============================] - 1s 10ms/step - loss: 1.6631 - class_output_loss: 1.0912 - bbox_output_loss: 0.4764 - class_output_accuracy: 0.5284 - bbox_output_mse: 0.4764 - val_loss: 1.5665 - val_class_output_loss: 1.4102 - val_bbox_output_loss: 0.0641 - val_class_output_accuracy: 0.3000 - val_bbox_output_mse: 0.0641
# Epoch 3/200
# 88/88 [==============================] - 1s 10ms/step - loss: 1.2981 - class_output_loss: 0.9383 - bbox_output_loss: 0.2689 - class_output_accuracy: 0.6193 - bbox_output_mse: 0.2689 - val_loss: 1.0940 - val_class_output_loss: 0.9408 - val_bbox_output_loss: 0.0632 - val_class_output_accuracy: 0.8000 - val_bbox_output_mse: 0.0632
# Epoch 4/200
# 88/88 [==============================] - 1s 10ms/step - loss: 1.2144 - class_output_loss: 0.8379 - bbox_output_loss: 0.2867 - class_output_accuracy: 0.6534 - bbox_output_mse: 0.2867 - val_loss: 1.0777 - val_class_output_loss: 0.9270 - val_bbox_output_loss: 0.0612 - val_class_output_accuracy: 0.8000 - val_bbox_output_mse: 0.0612
# Epoch 5/200
# 88/88 [==============================] - 1s 10ms/step - loss: 1.1179 - class_output_loss: 0.7988 - bbox_output_loss: 0.2296 - class_output_accuracy: 0.6818 - bbox_output_mse: 0.2296 - val_loss: 0.9610 - val_class_output_loss: 0.8381 - val_bbox_output_loss: 0.0335 - val_class_output_accuracy: 0.9000 - val_bbox_output_mse: 0.0335
# Epoch 6/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.9934 - class_output_loss: 0.6838 - bbox_output_loss: 0.2202 - class_output_accuracy: 0.7784 - bbox_output_mse: 0.2202 - val_loss: 0.9289 - val_class_output_loss: 0.8023 - val_bbox_output_loss: 0.0372 - val_class_output_accuracy: 0.8000 - val_bbox_output_mse: 0.0372
# Epoch 7/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.9722 - class_output_loss: 0.6597 - bbox_output_loss: 0.2231 - class_output_accuracy: 0.7784 - bbox_output_mse: 0.2231 - val_loss: 0.8497 - val_class_output_loss: 0.7147 - val_bbox_output_loss: 0.0456 - val_class_output_accuracy: 0.8000 - val_bbox_output_mse: 0.0456
# Epoch 8/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.9295 - class_output_loss: 0.5946 - bbox_output_loss: 0.2455 - class_output_accuracy: 0.7898 - bbox_output_mse: 0.2455 - val_loss: 0.8360 - val_class_output_loss: 0.7003 - val_bbox_output_loss: 0.0463 - val_class_output_accuracy: 0.8000 - val_bbox_output_mse: 0.0463
# Epoch 9/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.8194 - class_output_loss: 0.4923 - bbox_output_loss: 0.2377 - class_output_accuracy: 0.8409 - bbox_output_mse: 0.2377 - val_loss: 1.0326 - val_class_output_loss: 0.8835 - val_bbox_output_loss: 0.0597 - val_class_output_accuracy: 0.8000 - val_bbox_output_mse: 0.0597
# Epoch 10/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0
200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.0813 - class_output_loss: 0.0220 - bbox_output_loss: 0.0159 - class_output_accuracy: 0.9886 - bbox_output_mse: 0.0159 - val_loss: 1.5103 - val_class_output_loss: 1.4530 - val_bbox_output_loss: 0.0141 - val_class_output_accuracy: 0.7000 - val_bbox_output_mse: 0.0141
# Epoch 192/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.0636 - class_output_loss: 0.0048 - bbox_output_loss: 0.0159 - class_output_accuracy: 1.0000 - bbox_output_mse: 0.0159 - val_loss: 1.0695 - val_class_output_loss: 1.0055 - val_bbox_output_loss: 0.0213 - val_class_output_accuracy: 0.8000 - val_bbox_output_mse: 0.0213
# Epoch 193/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.0675 - class_output_loss: 0.0097 - bbox_output_loss: 0.0154 - class_output_accuracy: 1.0000 - bbox_output_mse: 0.0154 - val_loss: 0.3815 - val_class_output_loss: 0.3144 - val_bbox_output_loss: 0.0249 - val_class_output_accuracy: 0.9000 - val_bbox_output_mse: 0.0249
# Epoch 194/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.1423 - class_output_loss: 0.0803 - bbox_output_loss: 0.0200 - class_output_accuracy: 0.9602 - bbox_output_mse: 0.0200 - val_loss: 2.0718 - val_class_output_loss: 1.9975 - val_bbox_output_loss: 0.0325 - val_class_output_accuracy: 0.7000 - val_bbox_output_mse: 0.0325
# Epoch 195/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.1521 - class_output_loss: 0.0882 - bbox_output_loss: 0.0223 - class_output_accuracy: 0.9716 - bbox_output_mse: 0.0223 - val_loss: 1.9184 - val_class_output_loss: 1.8573 - val_bbox_output_loss: 0.0197 - val_class_output_accuracy: 0.5000 - val_bbox_output_mse: 0.0197
# Epoch 196/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.0676 - class_output_loss: 0.0093 - bbox_output_loss: 0.0171 - class_output_accuracy: 0.9943 - bbox_output_mse: 0.0171 - val_loss: 1.4218 - val_class_output_loss: 1.3591 - val_bbox_output_loss: 0.0217 - val_class_output_accuracy: 0.6000 - val_bbox_output_mse: 0.0217
# Epoch 197/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.0638 - class_output_loss: 0.0064 - bbox_output_loss: 0.0167 - class_output_accuracy: 1.0000 - bbox_output_mse: 0.0167 - val_loss: 1.7644 - val_class_output_loss: 1.7040 - val_bbox_output_loss: 0.0199 - val_class_output_accuracy: 0.7000 - val_bbox_output_mse: 0.0199
# Epoch 198/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.0567 - class_output_loss: 0.0011 - bbox_output_loss: 0.0153 - class_output_accuracy: 1.0000 - bbox_output_mse: 0.0153 - val_loss: 1.8785 - val_class_output_loss: 1.8123 - val_bbox_output_loss: 0.0261 - val_class_output_accuracy: 0.6000 - val_bbox_output_mse: 0.0261
# Epoch 199/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.0650 - class_output_loss: 0.0067 - bbox_output_loss: 0.0185 - class_output_accuracy: 1.0000 - bbox_output_mse: 0.0185 - val_loss: 1.5893 - val_class_output_loss: 1.5353 - val_bbox_output_loss: 0.0144 - val_class_output_accuracy: 0.7000 - val_bbox_output_mse: 0.0144
# Epoch 200/200
# 88/88 [==============================] - 1s 10ms/step - loss: 0.0570 - class_output_loss: 0.0021 - bbox_output_loss: 0.0156 - class_output_accuracy: 1.0000 - bbox_output_mse: 0.0156 - val_loss: 1.4174 - val_class_output_loss: 1.3607 - val_bbox_output_loss: 0.0176 - val_class_output_accuracy: 0.7000 - val_bbox_output_mse: 0.0176

# %%
y[0]
# Out:
# array([  1,  23,  42, 206, 199])

# %%
bbox_train[0]
# Out:
# array([0.24229075, 0.13215859, 0.73568282, 0.9339207 ])

# %%
results = pd.DataFrame(r.history)
results.tail()
# Out:
#          loss  class_output_loss  bbox_output_loss  class_output_accuracy  \
# 195  0.067624           0.009276          0.017123               0.994318
# 196  0.063827           0.006374          0.016700               1.000000
# 197  0.056712           0.001124          0.015312               1.000000
# 198  0.065045           0.006710          0.018522               1.000000
# 199  0.057001           0.002105          0.015552               1.000000
#
#      bbox_output_mse  val_loss  val_class_output_loss  val_bbox_output_loss  \
# 195         0.017123  1.421798               1.359127              0.021684
# 196         0.016700  1.764435               1.703988              0.019929
# 197         0.015312  1.878477               1.812310              0.026139
# 198         0.018522  1.589316               1.535299              0.014437
# 199         0.015552  1.417367               1.360678              0.017582
#
#      val_class_output_accuracy  val_bbox_output_mse
# 195                        0.6             0.021684
# 196                        0.7             0.019929
# 197                        0.6             0.026139
# 198                        0.7             0.014437
# 199                        0.7             0.017582

# %%
image= X_test[0]
img=image
image = np.expand_dims(image, axis=0)

# %%
image.shape
# Out:
# (1, 227, 227, 1)

# %%
predictions = model.predict(image)
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
predictions
# Out:
# [array([[1.5055006e-06, 4.1476137e-04, 6.1441474e-03, 9.9343961e-01]],
#        dtype=float32),
#  array([[0.22223422, 0.16949025, 0.59648955, 0.7118534 ]], dtype=float32)]

# %%
categ, bbox = model.predict(image)
bbox
# Out:
# 1/1 [==============================] - 0s 21ms/step
# array([[0.22223422, 0.16949025, 0.59648955, 0.7118534 ]], dtype=float32)

# %%
pred_bbox = predictions[1]
pred_bbox.flatten()
pred_bbox = pred_bbox*[227,227,227,227]
pred_bbox = pred_bbox.astype(int)
pred_bbox = pred_bbox[0]

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.imshow(img)
rect = patches.Rectangle(
    (pred_bbox[0], pred_bbox[1]),           # Bottom-left corner
    pred_bbox[2] - pred_bbox[0],            # Width
    pred_bbox[3] - pred_bbox[1],            # Height
    linewidth=2, edgecolor='cyan', facecolor='none'
)
ax.add_patch(rect)

# Remove axis and display
ax.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

def predict_single_image_from_test(X_test, model, image_index=0):
    """
    Predicts the class and bounding box for a single image from X_test.

    Args:
    X_test: numpy array of shape (N, 227, 227, 1), where N is the number of test images.
    model: trained Keras model instance.
    image_index: index of the image in X_test (default is 0).
    """
    # Select the image at the specified index
    image = X_test[image_index]  # Shape will be (227, 227, 1)

    # Normalize the image if it's not already normalized (ensure it's in [0, 1])
    image = image / 255.0  # Normalize to the range [0, 1]

    # Make the prediction (expand dimensions to add batch size)
    image = np.expand_dims(image, axis=0)  # Shape becomes (1, 227, 227, 1)

    # Get model predictions
    categ, bbox = model.predict(image)

    # Get the predicted class (highest probability)
    predicted_class = np.argmax(categ)

    # Flatten the bounding box and denormalize it (if necessary)
    bbox = bbox.flatten()  # Flatten from (1, 4) to (4,)
    bbox = bbox * [227, 227, 227, 227]  # Denormalize to pixel coordinates (assuming image size is 227x227)
    bbox = bbox.astype(int)

    # Map class index to the corresponding label (if applicable)
    class_labels = {1: 'Cucumber', 2: 'Egg Plant', 3: 'Mushroom'}
    prediction_label = class_labels.get(predicted_class, 'Unknown')

    # Draw the bounding box on the image
    image_with_bbox = np.squeeze(image, axis=0)  # Remove batch dimension
    image_with_bbox = cv2.rectangle(image_with_bbox, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (255, 0, 0), 2)

    # Add the class label text to the image
    image_with_bbox = cv2.putText(image_with_bbox, prediction_label, (bbox[0], bbox[1] - 4),
                                  cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    # Display the image with bounding box and label
    plt.figure(figsize=(6, 6))
    plt.imshow(image_with_bbox, cmap='gray')  # Since it's grayscale
    plt.axis('off')
    plt.show()

    return predicted_class, bbox, image_with_bbox
